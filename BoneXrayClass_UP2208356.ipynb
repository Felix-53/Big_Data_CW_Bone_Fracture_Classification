# %%
DATA_DIR = "data/Bone Fracture X-ray Dataset Simple vs. Comminuted Fractures/Bone Fracture X-ray Dataset Simple vs. Comminuted Fractures/Bone Fracture/Bone Fracture/Orginal"

CLASSES = ['Comminuted Bone Fracture', 'Simple Bone Fracture']
